# %%
from euler import *
from rk4 import *
from plot import *

# %% [markdown]
# ## Exercício 1 - EP MECOMP

# %% [markdown]
# ## Euler

# %% [markdown]
# ### Euler, velocidade 1x - passos diferente

# %%
f0 = np.array([
    0, #teta1
    0, #teta2
    0.05, #teta 11
    0.1, #teta21
    0,
    0,
  ])

# %%
response_euler = euler_steps(60, 0.01 , f0)
plot_values(response_euler, metodo='Euler', passo=0.01)

# %%
response_euler = euler_steps(60, 0.005 , f0)
plot_values(response_euler, metodo='Euler', passo=0.005)

# %%
response_euler = euler_steps(60, 0.002 , f0)
plot_values(response_euler, metodo='Euler', passo=0.002)

# %%
response_euler = euler_steps(60, 0.001 , f0)
plot_values(response_euler, metodo='Euler', passo=0.001)

# %%
response_euler = euler_steps(60, 0.0001 , f0)
plot_values(response_euler, metodo='Euler', passo=0.0001)

# %% [markdown]
# ### Euler, velocidade 2x

# %%
f0 = np.array([
    0, #teta1
    0, #teta2
    0.05*2, #teta 11
    0.1*2, #teta21
    0,
    0,
  ])

# %%
response_euler = euler_steps(60, 0.0005 , f0)
plot_values(response_euler, metodo='Euler', passo=0.0005)

# %% [markdown]
# ### Euler, velocidade 10x

# %%
f0 = np.array([
    0, #teta1
    0, #teta2
    0.05*10, #teta 11
    0.1*10, #teta21
    0,
    0,
  ])

# %%
response_euler = euler_steps(60, 0.0005 , f0)
plot_values(response_euler, metodo='Euler', passo=0.0005)

# %% [markdown]
# ## RK4

# %% [markdown]
# ### RK4, velocidade 1x - passos diferentes

# %%
f0 = np.array([
    0, #teta1
    0, #teta2
    0.05, #teta 11
    0.1, #teta21
    0,
    0,
  ])

# %%
response_rk4 = rk4_steps(60, 0.01 , f0)
plot_values(response_rk4, metodo='Euler', passo=0.01)

# %%
response_rk4 = rk4_steps(60, 0.005 , f0)
plot_values(response_rk4, metodo='Euler', passo=0.005)

# %%
response_rk4 = rk4_steps(60, 0.001 , f0)
plot_values(response_rk4, metodo='Euler', passo=0.001)

# %%
response_rk4 = rk4_steps(60, 0.0001 , f0)
plot_values(response_rk4, metodo='Euler', passo=0.0001)

# %% [markdown]
# ### Rk4, velocidade 2x

# %%
f0 = np.array([
    0, #teta1
    0, #teta2
    0.05*2, #teta 11
    0.1*2, #teta21
    0,
    0,
  ])

# %%
response_rk4 = rk4_steps(60, 0.0005 , f0)
plot_values(response_rk4, metodo='Euler', passo=0.0005)

# %% [markdown]
# ### Rk4, velocidade 10x

# %%
f0 = np.array([
    0, #teta1
    0, #teta2
    0.05*10, #teta 11
    0.1*10, #teta21
    0,
    0,
  ])

# %%
response_rk4 = rk4_steps(60, 0.0005 , f0)
plot_values(response_rk4, metodo='Euler', passo=0.0005)
