# %% [markdown]
# # Exercício 2 - MecComp

# %%
from main import *
from utils import *

# %%
delta = 0.1
uy = 0
w = 1
h = 4
lamb = 1.85
iter = 1000
tolerance = 1e-2
rho = 1
g = 9.8
p2 = 1e5
corrente_inicial = 0
p_init = 1e5

# %% [markdown]
# ## Angulo = 15 graus

# %% [markdown]
# ### Velocidade = 30 m/s

# %%
angle = 15
u_inf = 30

# %%
rect = Retangle(-2,-0.5,angle, u_inf, delta, uy, corrente_inicial, p_init, h, w)
rede = Mesh(rect, u_inf, delta, tolerance, lamb, h,corrente_inicial, uy, p_init, iter, rho, g)

# %%
rede.update_mask()
rede.plot_mask()

# %%
rede.update_corrente()
rede.plot_corrente()

# %%
rede.update_velocidade()
rede.plot_velocidade()

# %%
rede.update_pressure()
rede.plot_pressure()

# %%
rede.update_normal()
rede.plot_normal()

# %%
rede.get_arrasto()
# Out:
# np.float64(2707.223300773572)

# %%
rede.get_sust()
# Out:
# np.float64(-3618.336900280742)

# %% [markdown]
# ### Velocidade = 10 m/s

# %%
angle = 15
u_inf = 10

# %%
rect = Retangle(-2,-0.5,angle, u_inf, delta, uy, corrente_inicial, p_init, h, w)
rede = Mesh(rect, u_inf, delta, tolerance, lamb, h,corrente_inicial, uy, p_init, iter, rho, g)
rede.update_mask()

# %%
rede.update_corrente()
rede.plot_corrente()

# %%
rede.update_velocidade()
rede.plot_velocidade()

# %%
rede.update_pressure()
rede.plot_pressure()
rede.update_normal()

# %%
rede.get_arrasto()
# Out:
# np.float64(300.80258897479797)

# %%
rede.get_sust()
# Out:
# np.float64(-402.0374333644752)

# %% [markdown]
# ### Velocidade = 90 m/s

# %%
angle = 15
u_inf = 90

# %%
rect = Retangle(-2,-0.5,angle, u_inf, delta, uy, corrente_inicial, p_init, h, w)
rede = Mesh(rect, u_inf, delta, tolerance, lamb, h,corrente_inicial, uy, p_init, iter, rho, g)
rede.update_mask()

# %%
rede.update_corrente()
rede.plot_corrente()

# %%
rede.update_velocidade()
rede.plot_velocidade()

# %%
rede.update_pressure()
rede.plot_pressure()
rede.update_normal()

# %%
rede.get_arrasto()
# Out:
# np.float64(24365.009706962708)

# %%
rede.get_sust()
# Out:
# np.float64(-32565.032102527097)
